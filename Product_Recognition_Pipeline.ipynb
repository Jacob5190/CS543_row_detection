# %% [markdown]
# # Product Recognition Pipeline Setup & Training
#
# This notebook will install the required dependencies and run the Product Recognition training script on the SHAPE dataset.
#
# **Note on Dataset Placement:** If you transfer this folder to a new computer (like a GPU-enabled machine), make sure that the `training_set` and `test_set` directories are placed directly inside this `shelf_management` folder! Currently you may be using symbolic links on your Mac.

# %% [markdown]
# ## Environment Setup
# Choose **ONE** of the three installation blocks below depending on your current computer's hardware.

# %%
# OPTION 1: Apple Silicon (M1/M2/M3 Macs)
# Run this cell to ensure TensorFlow utilizes your built-in Metal GPU cores.
# !pip install tensorflow-macos~=2.13.0 tensorflow-metal tensorflow-addons~=0.21.0 faiss-cpu~=1.7.4
# Out:
# Requirement already satisfied: tensorflow-macos~=2.13.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (2.13.1)
# Collecting tensorflow-metal
#   Using cached tensorflow_metal-1.2.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (1.3 kB)
# Requirement already satisfied: tensorflow-addons~=0.21.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: faiss-cpu~=1.7.4 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (25.12.19)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (3.4.0)
# Requirement already satisfied: packaging in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (26.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (4.25.9)
# Requirement already satisfied: setuptools in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (3.1.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-macos~=2.13.0)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (1.74.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-macos~=2.13.0) (2.13.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorflow-addons~=0.21.0) (2.13.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (2.49.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (3.1.8)
# Requirement already satisfied: wheel>=0.26 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (0.47.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (45.0.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (2026.4.22)
# Requirement already satisfied: cffi>=1.14 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from cffi>=1.14->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (2.23)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (3.23.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos~=2.13.0) (3.0.3)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Using cached tensorflow_metal-1.2.0-cp39-cp39-macosx_12_0_arm64.whl (1.4 MB)
# Installing collected packages: typing-extensions, tensorflow-metal
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.032m0/2 [typing-extensions]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [tensorflow-metal]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# exceptiongroup 1.3.1 requires typing-extensions>=4.6.0; python_version < "3.13", but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed tensorflow-metal-1.2.0 typing-extensions-4.5.0

# %%
# OPTION 2: Windows/Linux with NVIDIA GPU (e.g. RTX 4050)
# Run this cell to install native TensorFlow and the GPU-accelerated version of FAISS.
# !pip install -r requirements.txt
# !pip install faiss-gpu
# !pip uninstall -y faiss-cpu

# %%
# OPTION 3: Standard CPU (Basic Windows/Linux Laptop)
# Run this cell if you don't have a dedicated GPU.
# !pip install -r requirements.txt

# %% [markdown]
# ## 1. Train the Recognition Model
#
# The command below trains the MobileNetV3-Large variant using Triplet Loss.
# If you run out of memory, simply reduce the `--batch_size 64` to `32` or `16`.

# %%
# !python recognition_training.py \
    --target_shape 224 \
    --embedding_size 256 \
    --batch_size 64 \
    --num_epochs 30 \
    --data_dir training_set
# Out:
# /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2026-04-27 20:02:32.892393: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2026-04-27 20:02:32.892556: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2026-04-27 20:02:32.892562: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2026-04-27 20:02:32.893772: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-04-27 20:02:32.893922: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/30
# 2026-04-27 20:02:41.638275: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 566/566 [==============================] - ETA: 0s - loss: 0.28272026-04-27 20:14:59.858674: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#
# Epoch 1: val_loss improved from inf to 0.60599, saving model to model
# 566/566 [==============================] - 798s 1s/step - loss: 0.2827 - val_loss: 0.6060
# Epoch 2/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2780
# Epoch 2: val_loss improved from 0.60599 to 0.49391, saving model to model
# 566/566 [==============================] - 738s 1s/step - loss: 0.2780 - val_loss: 0.4939
# Epoch 3/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2767
# Epoch 3: val_loss improved from 0.49391 to 0.44614, saving model to model
# 566/566 [==============================] - 667s 1s/step - loss: 0.2767 - val_loss: 0.4461
# Epoch 4/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2766
# Epoch 4: val_loss improved from 0.44614 to 0.40573, saving model to model
# 566/566 [==============================] - 812s 1s/step - loss: 0.2766 - val_loss: 0.4057
# Epoch 5/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2726
# Epoch 5: val_loss improved from 0.40573 to 0.39048, saving model to model
# 566/566 [==============================] - 813s 1s/step - loss: 0.2726 - val_loss: 0.3905
# Epoch 6/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2739
# Epoch 6: val_loss improved from 0.39048 to 0.37703, saving model to model
# 566/566 [==============================] - 1033s 2s/step - loss: 0.2739 - val_loss: 0.3770
# Epoch 7/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2724
# Epoch 7: val_loss improved from 0.37703 to 0.37145, saving model to model
# 566/566 [==============================] - 930s 2s/step - loss: 0.2724 - val_loss: 0.3714
# Epoch 8/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2715
# Epoch 8: val_loss improved from 0.37145 to 0.32572, saving model to model
# 566/566 [==============================] - 865s 2s/step - loss: 0.2715 - val_loss: 0.3257
# Epoch 9/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2693
# Epoch 9: val_loss improved from 0.32572 to 0.31203, saving model to model
# 566/566 [==============================] - 954s 2s/step - loss: 0.2693 - val_loss: 0.3120
# Epoch 10/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2693
# Epoch 10: val_loss did not improve from 0.31203
# 566/566 [==============================] - 919s 2s/step - loss: 0.2693 - val_loss: 0.3197
# Epoch 11/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2694
# Epoch 11: val_loss improved from 0.31203 to 0.30641, saving model to model
# 566/566 [==============================] - 736s 1s/step - loss: 0.2694 - val_loss: 0.3064
# Epoch 12/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2669
# Epoch 12: val_loss did not improve from 0.30641
# 566/566 [==============================] - 871s 2s/step - loss: 0.2669 - val_loss: 0.3457
# Epoch 13/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2687
# Epoch 13: val_loss did not improve from 0.30641
# 566/566 [==============================] - 1128s 2s/step - loss: 0.2687 - val_loss: 0.3208
# Epoch 14/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2676
# Epoch 14: val_loss did not improve from 0.30641
# 566/566 [==============================] - 625s 1s/step - loss: 0.2676 - val_loss: 0.3255
# Epoch 15/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2657
# Epoch 15: val_loss improved from 0.30641 to 0.29674, saving model to model
# 566/566 [==============================] - 569s 1s/step - loss: 0.2657 - val_loss: 0.2967
# Epoch 16/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2661
# Epoch 16: val_loss did not improve from 0.29674
# 566/566 [==============================] - 585s 1s/step - loss: 0.2661 - val_loss: 0.3601
# Epoch 17/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2657
# Epoch 17: val_loss did not improve from 0.29674
# 566/566 [==============================] - 627s 1s/step - loss: 0.2657 - val_loss: 0.3550
# Epoch 18/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2659
# Epoch 18: val_loss did not improve from 0.29674
# 566/566 [==============================] - 603s 1s/step - loss: 0.2659 - val_loss: 0.3115
# Epoch 19/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2650
# Epoch 19: val_loss did not improve from 0.29674
# 566/566 [==============================] - 588s 1s/step - loss: 0.2650 - val_loss: 0.4984
# Epoch 20/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2651
# Epoch 20: val_loss did not improve from 0.29674
# 566/566 [==============================] - 602s 1s/step - loss: 0.2651 - val_loss: 0.3668
# Epoch 21/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2640
# Epoch 21: val_loss did not improve from 0.29674
# 566/566 [==============================] - 584s 1s/step - loss: 0.2640 - val_loss: 0.4603
# Epoch 22/30
# 566/566 [==============================] - ETA: 0s - loss: 0.2647
# Epoch 22: val_loss did not improve from 0.29674
# 566/566 [==============================] - 609s 1s/step - loss: 0.2647 - val_loss: 0.4196
# Epoch 22: early stopping

# %% [markdown]
# ## 2. Test the Recognition Model
#
# Once training is complete, the model will be evaluated against the test set.
# This process will compute gallery embeddings on-the-fly and save them to `embeddings.pickle`.

# %%
# !python recognition_test.py \
    --target_shape 224 \
    --embedding_size 256 \
    --batch_size 64 \
    --data_dir_gallery training_set \
    --data_dir_test test_set \
    --model model
# Out:
# /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/samuel/Workspace/Class/SP26/CS543/Project/.venv/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2026-04-28 00:59:02.095708: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2026-04-28 00:59:02.095911: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2026-04-28 00:59:02.095918: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2026-04-28 00:59:02.095983: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-04-28 00:59:02.096331: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Starting prediction ...
# 2026-04-28 00:59:11.553311: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 708/708 [==============================] - ETA: 0sInference time per Image: 0.0036977567413021377 seconds
# 708/708 [==============================] - 167s 235ms/step
# Starting prediction ...
# 13/13 [==============================] - ETA: 0sInference time per Image: 9.843947533191845e-05 seconds
# 13/13 [==============================] - 4s 354ms/step
# 4.342297346389602e-05 seconds
# Accuracy: 0.8634686346863468
# Accuracy top 5: 0.949569495694957
# Accuracy top 10: 0.959409594095941
