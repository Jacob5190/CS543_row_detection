# %% [markdown]
# # Product Recognition Pipeline Setup & Training
#
# This notebook will install the required dependencies and run the Product Recognition training script on the SHAPE dataset.
#
# **Note on Dataset Placement:** If you transfer this folder to a new computer (like a GPU-enabled machine), make sure that the `training_set` and `test_set` directories are placed directly inside this `shelf_management` folder! Currently you may be using symbolic links on your Mac.

# %% [markdown]
# ## Environment Setup
# Choose **ONE** of the three installation blocks below depending on your current computer's hardware.

# %%
# OPTION 1: Apple Silicon (M1/M2/M3 Macs)
# Run this cell to ensure TensorFlow utilizes your built-in Metal GPU cores.
# !pip install tensorflow-macos~=2.13.0 tensorflow-metal tensorflow-addons~=0.21.0 faiss-cpu~=1.7.4
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-macos~=2.13.0 (from versions: none)
# ERROR: No matching distribution found for tensorflow-macos~=2.13.0

# %%
# OPTION 2: Windows/Linux with NVIDIA GPU (e.g. RTX 4050)
# Run this cell to install native TensorFlow and the GPU-accelerated version of FAISS.
# !pip install -r requirements.txt
# !pip install faiss-gpu
# !pip uninstall -y faiss-cpu
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu
# WARNING: Skipping faiss-cpu as it is not installed.

# %%
# OPTION 3: Standard CPU (Basic Windows/Linux Laptop)
# Run this cell if you don't have a dedicated GPU.
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.21.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (4.4 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached wrapt-2.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.4 kB)
# ...
#   Using cached grpcio-1.80.0-cp313-cp313-macosx_11_0_universal2.whl.metadata (3.8 kB)
# ...
#   Using cached numpy-2.4.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...

# %% [markdown]
# ## 1. Train the Recognition Model
#
# The command below trains the MobileNetV3-Large variant using Triplet Loss.
# If you run out of memory, simply reduce the `--batch_size 64` to `32` or `16`.

# %%
# !python recognition_training.py \
    --target_shape 224 \
    --embedding_size 256 \
    --batch_size 64 \
    --num_epochs 30 \
    --data_dir training_set
# Out:
# Traceback (most recent call last):
#   File "/Users/dipali/Documents/Coursework/ACV/Final_projectt/CS543_row_detection/scripts/recognition_training.py", line 6, in <module>
#     import tensorflow_addons as tfa
# ModuleNotFoundError: No module named 'tensorflow_addons'

# %% [markdown]
# ## 2. Test the Recognition Model
#
# Once training is complete, the model will be evaluated against the test set.
# This process will compute gallery embeddings on-the-fly and save them to `embeddings.pickle`.

# %%
# !python recognition_test.py \
    --target_shape 224 \
    --embedding_size 256 \
    --batch_size 64 \
    --data_dir_gallery training_set \
    --data_dir_test test_set \
    --model model
# Out:
# Traceback (most recent call last):
#   File "/Users/dipali/Documents/Coursework/ACV/Final_projectt/CS543_row_detection/scripts/recognition_test.py", line 4, in <module>
#     from recognition_training import read_image
#   File "/Users/dipali/Documents/Coursework/ACV/Final_projectt/CS543_row_detection/scripts/recognition_training.py", line 6, in <module>
#     import tensorflow_addons as tfa
# ModuleNotFoundError: No module named 'tensorflow_addons'
